# %%
import requests
from bs4 import BeautifulSoup
from IPython.display import display, Markdown
import ollama

# %%
MODEL = "llama3.2"

# %%
# A class to represent a Webpage

class Website:
    """
    A utility class to represent a Website that we have scraped
    """
    url: str
    title: str
    text: str

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
web = Website("https://anthropic.com")

# %%
print(web.title)
# Out:
# Home \ Anthropic

# %%
print(web.text)
# Out:
# Skip to main content
# Skip to footer
# Research
# Economic Futures
# Commitments
# Initiatives
# Claude's Constitution
# Transparency
# Responsible Scaling Policy
# Trust center
# Security and compliance
# Learn
# Learn
# Anthropic Academy
# Tutorials
# Use cases
# Engineering at Anthropic
# Developer docs
# Company
# About
# Careers
# Events
# News
# Try Claude
# Try Claude
# Try Claude
# Learn more about Claude
# Products
# Claude
# Claude Code
# Claude Cowork
# Claude Platform
# Pricing
# Contact sales
# Models
# Opus
# Sonnet
# Haiku
# Log in
# Claude.ai
# Claude Console
# EN
# This is some text inside of a div block.
# Log in to Claude
# Log in to Claude
# Log in to Claude
# Download app
# Download app
# Download app
# Research
# Economic Futures
# Commitments
# Initiatives
# Claude's Constitution
# Transparency
# Responsible Scaling Policy
# Trust center
# Security and compliance
# Learn
# Learn
# Anthropic Academy
# Tutorials
# Use cases
# Engineering at Anthropic
# ...

# %%
# Design system prompt 

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "The contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %% [markdown]
# #Ollama

# %%
#call ollama func
def summarize(url):
    website = Website(url)
    messages = messages_for(website)
    response = ollama.chat(model=MODEL, messages=messages)
    return response['message']['content']

# %%
summarize("https://www.vietnamplus.vn/tong-bi-thu-chu-tri-hop-thuong-truc-ban-chi-dao-ve-phat-trien-khoa-hoc-cong-nghe-post1098519.vnp")
# Out:
# "# Anthropic Website Summary\n\n## Overview\nAnthropic is a public benefit corporation dedicated to securing the benefits and mitigating the risks of AI. The website provides information on the company's research, products, and initiatives aimed at promoting safe and beneficial AI development.\n\n## Research and Initiatives\nAnthropic is involved in various research and initiatives, including:\n\n* Economic Futures: Exploring the economic implications of AI\n* Commitments: Outlining the company's goals and values\n* Initiatives: Describing projects and efforts to advance AI safety and responsible scaling\n\n## AI Safety and Responsible Scaling\nThe company's core views on AI safety include:\n\n* Alignment Science: Researching methods to align AI with human values\n* Responsible Scaling Policy: Guidelines for scaling AI development responsibly\n* Anthropic's Constitution: A framework for guiding the company's actions\n\n## Products and Services\nAnthropic offers various products and s
# ...

# %%
# A function to display this nicely in the Jupyter output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://www.vietnamplus.vn/tong-bi-thu-chu-tri-hop-thuong-truc-ban-chi-dao-ve-phat-trien-khoa-hoc-cong-nghe-post1098519.vnp")
# Out:
# ### Tóm tắt trang web Tổng Bí thư chủ trì họp Thường trực Ban Chỉ đạo về phát triển khoa học công nghệ
#
# **Tổng Bí thư Tô Lâm phát biểu tại họp Thường trực Ban Chỉ đạo về phát triển khoa học công nghệ**
#
# * Tổng Bí thư Tô Lâm là người đứng đầu Ban Chỉ đạo về phát triển khoa học công nghệ, đổi mới sáng tạo và chuyển đổi số.
# * Ông chủ trì phiên họp thứ nhất của Ban Chỉ đạo này.
#
# **Tin liên quan**
#
# * Các tin tức liên quan đến phát triển khoa học công nghệ, chuyển đổi số, và các dự án quan trọng trong lĩnh vực này.
# * Các tin tức khác không liên quan đến chủ đề phát triển khoa học công nghệ.
#
# ### Kết luận
#
# Trang web Tổng Bí thư chủ trì họp Thường trực Ban Chỉ đạo về phát triển khoa học công nghệ cung cấp thông tin về các hoạt động và quyết định liên quan đến phát triển khoa học công nghệ và chuyển đổi số. Trang web cũng cung cấp các tin tức khác không liên quan đến chủ đề này.
